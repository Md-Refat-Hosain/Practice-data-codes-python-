# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Refat-Hosain/Practice-data-codes-python-/blob/main/DSL_porject_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import nececcery libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import statistics as st

# Libraries For Text

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import confusion_matrix
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read dataset

# %%
df = pd.read_csv('//content/drive/MyDrive/DSL projects/project - 3/file (1).csv')
df
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
# check for null values

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
# drop null(fully null) columns

# %%
df.drop(columns='country_name' , axis = 1 , inplace = True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
# Man or Women stopped more?

# %%
    # way - 1

# %%
df.head(3)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
# 2      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False
# 2       False      0-15 Min               False

# %%
spd_vio = df[df['violation']=='Speeding']

# %%
spd_vio.groupby('driver_gender').count()
# Out:
#                stop_date  stop_time  driver_age_raw  driver_age  driver_race  \
# driver_gender
# F                  11686      11686           11686       11661        11686
# M                  25517      25517           25517       25458        25517
#
#                violation_raw  violation  search_conducted  search_type  \
# driver_gender
# F                      11686      11686             11686          102
# M                      25517      25517             25517          694
#
#                stop_outcome  is_arrested  stop_duration  drugs_related_stop
# driver_gender
# F                     11686        11686          11686               11686
# M                     25517        25517          25517               25517

# %%
    # way - 2

# %%
df[df['violation']=='Speeding'].driver_gender.value_counts() # note: job of 'value_counts()' is to add up occurences of all unique values present in a column.
# Out:
# driver_gender
# M    25517
# F    11686
# Name: count, dtype: int64

# %%
# Does gender effects on search during a stop?

    # Way -1

# %%
df.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %%
df['search_conducted'].value_counts()
# Out:
# search_conducted
# False    63056
# True      2479
# Name: count, dtype: int64

# %%
df.groupby('driver_gender').count()
# Out:
#                stop_date  stop_time  driver_age_raw  driver_age  driver_race  \
# driver_gender
# F                  16310      16310           16309       16275        16310
# M                  45164      45164           45164       44947        45164
#
#                violation_raw  violation  search_conducted  search_type  \
# driver_gender
# F                      16310      16310             16310          366
# M                      45164      45164             45164         2113
#
#                stop_outcome  is_arrested  stop_duration  drugs_related_stop
# driver_gender
# F                     16310        16310          16310               16310
# M                     45164        45164          45164               45164

# %%
m_sc_t = df[ (df['driver_gender'] == 'M') & (df['search_conducted'] ==True)]
fm_sc_t = df[(df['driver_gender'] == 'F') & (df['search_conducted'] ==True)]

# %%
Male_perc = m_sc_t.shape[0]/45164 *100
FMale_perc = fm_sc_t.shape[0]/16310 *100
Male_perc , FMale_perc # Yes there is a bias on Male
# Out:
# (4.678505003985475, 2.244022072348253)

# %%
    #   way - 2

# %%
df.groupby('driver_gender').search_conducted.sum() # note: here after making group by , if then we put any column that will show only true values not false.
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
# what is the mean stop_duration?

# %%
df.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested stop_duration  drugs_related_stop
# 0       False      0-15 Min               False
# 1       False      0-15 Min               False

# %%
df['stop_duration'].unique()
# Out:
# array(['0-15 Min', '16-30 Min', '30+ Min', nan, '2'], dtype=object)

# %%
df.stop_duration.value_counts()
# Out:
# stop_duration
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: count, dtype: int64

# %%
df['stop_duration'] = df['stop_duration'].map({'0-15 Min' : 7.5 , '16-30 Min':24 , '30+ Min': 45})

# %%
df['stop_duration'].mean()
# Out:
# 12.187420698181345

# %%
# age distribution on each violation

# %%
df.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
#
#   violation_raw violation  search_conducted search_type stop_outcome  \
# 0      Speeding  Speeding             False         NaN     Citation
# 1      Speeding  Speeding             False         NaN     Citation
#
#   is_arrested  stop_duration  drugs_related_stop
# 0       False            7.5               False
# 1       False            7.5               False

# %%
df.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
