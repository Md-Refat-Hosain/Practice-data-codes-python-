# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Refat-Hosain/Practice-data-codes-python-/blob/main/Random_forest_classifier_practice_(ud_cdm).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import statistics as st

# Libraries For Text

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import confusion_matrix
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Read dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Udemy ds course datasets/04+-+decisiontreeAdultIncome.csv')
df
# Out:
#        age        wc      education  marital status    race   gender  \
# 0       38   Private        HS-grad        Divorced   White     Male
# 1       28   Private      Bachelors         Married   Black   Female
# 2       37   Private        Masters         Married   White   Female
# 3       31   Private        Masters   Never-married   White   Female
# 4       42   Private      Bachelors         Married   White     Male
# ...    ...       ...            ...             ...     ...      ...
# 19782   53   Private        Masters         Married   White     Male
# 19783   22   Private   Some-college   Never-married   White     Male
# 19784   40   Private        HS-grad         Married   White     Male
# 19785   58   Private        HS-grad         Widowed   White   Female
# 19786   22   Private        HS-grad   Never-married   White     Male
#
#        hours per week IncomeClass
# 0                  40       <=50K
# 1                  40       <=50K
# ...

# %%
# check null values

# %%
df.isna().sum()
# Out:
# age               0
# wc                0
# education         0
# marital status    0
# race              0
# gender            0
# hours per week    0
# IncomeClass       0
# dtype: int64

# %%
# create dummy variables

# %%
data_prep = pd.get_dummies(df , drop_first= True )
data_prep
# Out:
#        age  hours per week  wc_ Local-gov  wc_ Never-worked  wc_ Private  \
# 0       38              40          False             False         True
# 1       28              40          False             False         True
# 2       37              40          False             False         True
# 3       31              50          False             False         True
# 4       42              40          False             False         True
# ...    ...             ...            ...               ...          ...
# 19782   53              40          False             False         True
# 19783   22              40          False             False         True
# 19784   40              40          False             False         True
# 19785   58              40          False             False         True
# 19786   22              20          False             False         True
#
#        education_ Doctorate  education_ HS-grad  education_ Masters  \
# ...

# %%
data_prep.columns
# Out:
# Index(['age', 'hours per week', 'wc_ Local-gov', 'wc_ Never-worked',
#        'wc_ Private', 'education_ Doctorate', 'education_ HS-grad',
#        'education_ Masters', 'education_ Preschool', 'education_ Prof-school',
#        'education_ Some-college', 'marital status_ Never-married',
#        'marital status_ Widowed', 'marital status_Married',
#        'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other', 'race_ White',
#        'gender_ Male', 'IncomeClass_ >50K'],
#       dtype='object')

# %%
data_prep[['wc_ Local-gov', 'wc_ Never-worked',
       'wc_ Private', 'education_ Doctorate', 'education_ HS-grad',
       'education_ Masters', 'education_ Preschool', 'education_ Prof-school',
       'education_ Some-college', 'marital status_ Never-married',
       'marital status_ Widowed', 'marital status_Married',
       'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other', 'race_ White',
       'gender_ Male', 'IncomeClass_ >50K']] = data_prep[['wc_ Local-gov', 'wc_ Never-worked',
       'wc_ Private', 'education_ Doctorate', 'education_ HS-grad',
       'education_ Masters', 'education_ Preschool', 'education_ Prof-school',
       'education_ Some-college', 'marital status_ Never-married',
       'marital status_ Widowed', 'marital status_Married',
       'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other', 'race_ White',
       'gender_ Male', 'IncomeClass_ >50K']].astype('int')


data_prep
# Out:
#        age  hours per week  wc_ Local-gov  wc_ Never-worked  wc_ Private  \
# 0       38              40              0                 0            1
# 1       28              40              0                 0            1
# 2       37              40              0                 0            1
# 3       31              50              0                 0            1
# 4       42              40              0                 0            1
# ...    ...             ...            ...               ...          ...
# 19782   53              40              0                 0            1
# 19783   22              40              0                 0            1
# 19784   40              40              0                 0            1
# 19785   58              40              0                 0            1
# 19786   22              20              0                 0            1
#
#        education_ Doctorate  education_ HS-grad  education_ Masters  \
# ...

# %%
X = data_prep.iloc[: , :-1]
y = data_prep.iloc[:,-1]

# %%
X_train , X_test , y_train , y_test = train_test_split( X , y , test_size= .3 , random_state= 42 , stratify= y)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state= 42)
rfc.fit(X_train , y_train)
y_preds = rfc.predict(X_test)

# %%
from sklearn.metrics import  confusion_matrix

# %%
cm = confusion_matrix(y_test , y_preds)
score = rfc.score(X_test , y_test)

# %%
cm , score
# Out:
# (array([[3834,  539],
#         [ 656,  908]]),
#  0.7987198922014486)
