# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Refat-Hosain/Practice-data-codes-python-/blob/main/Logistic_regression_on_Loan_prediction_(ud_cdm).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
import statistics as st

# Libraries For Text

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')



from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import confusion_matrix
# %matplotlib inline
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Read dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/ud ds+ml (logistic regress....)/01Exercise1.csv')
df
# Out:
#      gender married   ch  income  loanamt status
# 0      Male      No  1.0    5849      NaN      Y
# 1      Male     Yes  1.0    4583    128.0      N
# 2      Male     Yes  1.0    3000     66.0      Y
# 3      Male     Yes  1.0    2583    120.0      Y
# 4      Male      No  1.0    6000    141.0      Y
# ..      ...     ...  ...     ...      ...    ...
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N
#
# [614 rows x 6 columns]

# %%
# copy then clean dataset

# %%
LoanPrep = df.copy()

# %%
LoanPrep.shape
# Out:
# (614, 6)

# %%
LoanPrep.isnull().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
LoanPrep = LoanPrep.dropna()

# %%
LoanPrep.shape
# Out:
# (529, 6)

# %%
# create dummy variable for categorical values.

# %%
LoanPrep = LoanPrep.drop(['gender'] , axis = 1)

# %%
LoanPrep.columns
# Out:
# Index(['married', 'ch', 'income', 'loanamt', 'status'], dtype='object')

# %%
LoanPrep.head(4)
# Out:
#   married   ch  income  loanamt status
# 1     Yes  1.0    4583    128.0      N
# 2     Yes  1.0    3000     66.0      Y
# 3     Yes  1.0    2583    120.0      Y
# 4      No  1.0    6000    141.0      Y

# %%
LoanPrep[['married','status']] = LoanPrep[['married','status']].astype('category')

# %%
LoanPrep.dtypes
# Out:
# married    category
# ch          float64
# income        int64
# loanamt     float64
# status     category
# dtype: object

# %%
dummies = LoanPrep[['married','status']]
dummies = pd.get_dummies(dummies , drop_first= True)
dummies = dummies.astype('int')
LoanPrep = LoanPrep.drop(['married','status'] , axis= 1)
LoanPrep = pd.concat([dummies , LoanPrep] , axis= 1)

# %%
LoanPrep
# Out:
#      married_Yes  status_Y   ch  income  loanamt
# 1              1         0  1.0    4583    128.0
# 2              1         1  1.0    3000     66.0
# 3              1         1  1.0    2583    120.0
# 4              0         1  1.0    6000    141.0
# 5              1         1  1.0    5417    267.0
# ..           ...       ...  ...     ...      ...
# 609            0         1  1.0    2900     71.0
# 610            1         1  1.0    4106     40.0
# 611            1         1  1.0    8072    253.0
# 612            1         1  1.0    7583    187.0
# 613            0         0  0.0    4583    133.0
#
# [529 rows x 5 columns]

# %%
# Normalize the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar_ = StandardScaler()

# %%
LoanPrep['income'] = scalar_.fit_transform(LoanPrep[['income']])
LoanPrep['loanamt'] = scalar_.fit_transform(LoanPrep[['loanamt']])

# %%
LoanPrep
# Out:
#      married_Yes  status_Y   ch    income   loanamt
# 1              1         0  1.0 -0.128073 -0.194250
# 2              1         1  1.0 -0.392077 -0.971015
# 3              1         1  1.0 -0.461621 -0.294478
# 4              0         1  1.0  0.108246 -0.031380
# 5              1         1  1.0  0.011017  1.547205
# ..           ...       ...  ...       ...       ...
# 609            0         1  1.0 -0.408754 -0.908372
# 610            1         1  1.0 -0.207624 -1.296754
# 611            1         1  1.0  0.453802  1.371807
# 612            1         1  1.0  0.372249  0.544929
# 613            0         0  0.0 -0.128073 -0.131608
#
# [529 rows x 5 columns]

# %%
# Create the X and Y

# %%
y = LoanPrep['status_Y']
X = LoanPrep.drop(['status_Y'] , axis = 1)

# %%
# split for train and test

# %%
X_train , X_test , y_train , y_test = train_test_split( X , y , test_size= .3 , random_state= 42 , stratify= y)

# %%
# Build the logistic regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_preds = lr.predict(X_test)

# %%
# Build confusion matrix.

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test , y_preds)

# %%
cm
# Out:
# array([[ 25,  24],
#        [  0, 110]])

# %%
LoanPrep
# Out:
#      married_Yes  status_Y   ch    income   loanamt
# 1              1         0  1.0 -0.128073 -0.194250
# 2              1         1  1.0 -0.392077 -0.971015
# 3              1         1  1.0 -0.461621 -0.294478
# 4              0         1  1.0  0.108246 -0.031380
# 5              1         1  1.0  0.011017  1.547205
# ..           ...       ...  ...       ...       ...
# 609            0         1  1.0 -0.408754 -0.908372
# 610            1         1  1.0 -0.207624 -1.296754
# 611            1         1  1.0  0.453802  1.371807
# 612            1         1  1.0  0.372249  0.544929
# 613            0         0  0.0 -0.128073 -0.131608
#
# [529 rows x 5 columns]

# %%
score = lr.score(X_test , y_test )
score
# Out:
# 0.8490566037735849
